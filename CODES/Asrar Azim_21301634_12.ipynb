# %%
def function_name(l):
    
    
    l = elements.split(" ")
    nums = []
    letters = []
    finalList = []
    for i in l:
        if(ord(l[i]) >= 48 and ord(l[i]) <= 57):
            nums.append(i)

        else:
            letters.append(i)
        
    ratio = len(letters)/len(nums)
        
    if(len(nums) == 2*len(letters)):
        count = 0

        for i in range(len(nums)*len(letters)):
            if(count == 2):
                finalList.append(letters.pop(0))
                count = 0
            if(len(nums) == 0 or len(letters) == 0):
    
                break
            
            else:
                finalList.append(nums.pop(0))
                
                count = count + 1

    elif(int(ratio) > len(nums)):
        count = 0
        
        for i in range(len(nums)*len(letters)):
            if(count == 3):
                finalList.append(nums.pop(0))
                count = 0


            if(len(nums) == 0 or len(letters) == 0):
                break
            else:
                finalList.append(letters.pop(0))
                
                count = count + 1


    else:

        count = 0

        for i in range(len(nums)*len(letters)):

            if(count == 1):

                finalList.append(letters.pop(0))
                count = 0

            elif(len(nums) == 0 or len(letters) == 0):

                break

            else:

                finalList.append(nums.pop(0))

                count = count + 1

    print(int(finalList))

function_name(['2', 'r', '6', '7', 'a', '4', 'b', '7', '9', 'c', 'd', '5', '3', '7', '0'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-88a7e502f370> in <module>
#      71     print(int(finalList))
#      72
# ---> 73 function_name(['2', 'r', '6', '7', 'a', '4', 'b', '7', '9', 'c', 'd', '5', '3', '7', '0'])
#
# <ipython-input-20-88a7e502f370> in function_name(l)
#       7     finalList = []
#       8     for i in l:
# ----> 9         if(ord(l[i]) >= 48 and ord(l[i]) <= 57):
#      10             nums.append(i)
#      11
#
# TypeError: list indices must be integers or slices, not str
