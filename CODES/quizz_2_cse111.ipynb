# %%
class Customer:
  def __init__(self,name,pass1="****"):
    self.name = name
    self.pass1 = pass1
    self.item = []
    self.unit = []
    self.dic = {}
    if self.pass1 !="****":
      print(f"User {self.name} has been created")
    elif self.pass1 == "****":
      print(f"{self.name}, password set to default.Needs to be changed")

  def addToCart(self,*args):
    self.args = args

    if self.pass1 !="****":
      for i in range(len(self.args)):
        if i%2==0:
          self.item.append(self.args[i])
        else:
          self.unit.append(self.args[i])

      for i in self.item:
        if i in product_list.keys():
          print(f"{i} added to {self.name}'s cart")
        elif i not in product_list.keys():
          print(f"Sorry! {i} not avalaible in product list ")

    for i in range(len(self.args)):
      value = 0
      if i%2==0:
        key = self.args[i]

      else:
        value = self.args[i]

      self.dic[key]=value
    print(self.dic)




  def setPassword(self,pass1):
    self.pass1 = pass1

  def printDetails(self):
    total_cost = 0
    total_price = 0
    print(f"Customer Name: {self.name}\nPassword: {self.pass1}\nCart Details:\nTotal Item: {len(self.item)}")
    for k,v in self.dic.items():
      total_price = product_list[k]*v
      print(f"Item: {k}, Unit: {v}, Per Unit Price: {product_list[k]}, Total price: {total_price}")
      total_cost +=total_price
    print(f"Total Cost: {total_cost}")


product_list={"Mango":100,"Ego Icecream":60,"Chocobar":25}
product_list["Beef"]=650
product_list["Chicken"]=250
product_list["Apple"] = 150
print("1.............")
customer1 = Customer("Alice","asdzxc1234")
print("2.............")
customer2 = Customer("Bob")
print("3.............")
customer1.addToCart("Mango",10,"Ego Icecream",4)
print("4.............")
customer2.addToCart("Beef",3,"Chicken",5)
print("5.............")
customer1.printDetails()
print("6.............")
customer2.printDetails()
print("7.............")
customer2.setPassword("qwerty12")
customer2.addToCart("Beef",3,"Chicken",5)
print("8.............")
customer2.addToCart("Lichi",100,"Apple",3)
print("9.............")
customer1.addToCart("Beef",4)
print("10............")
customer1.printDetails()
print("11............")
customer2.printDetails()
# Out:
# 1.............
# User Alice has been created
# 2.............
# Bob, password set to default.Needs to be changed
# 3.............
# Mango added to Alice's cart
# Ego Icecream added to Alice's cart
# {'Mango': 10, 'Ego Icecream': 4}
# 4.............
# {'Beef': 3, 'Chicken': 5}
# 5.............
# Customer Name: Alice
# Password: asdzxc1234
# Cart Details:
# Total Item: 2
# Item: Mango, Unit: 10, Per Unit Price: 100, Total price: 1000
# Item: Ego Icecream, Unit: 4, Per Unit Price: 60, Total price: 240
# Total Cost: 1240
# 6.............
# Customer Name: Bob
# Password: ****
# Cart Details:
# Total Item: 0
# Item: Beef, Unit: 3, Per Unit Price: 650, Total price: 1950
# Item: Chicken, Unit: 5, Per Unit Price: 250, Total price: 1250
# Total Cost: 3200
# 7.............
# Beef added to Bob's cart
# Chicken added to Bob's cart
# {'Beef': 3, 'Chicken': 5}
# 8.............
# Beef added to Bob's cart
# Chicken added to Bob's cart
# Sorry! Lichi not avalaible in product list
# Apple added to Bob's cart
# {'Beef': 3, 'Chicken': 5, 'Lichi': 100, 'Apple': 3}
# 9.............
# Mango added to Alice's cart
# Ego Icecream added to Alice's cart
# Beef added to Alice's cart
# {'Mango': 10, 'Ego Icecream': 4, 'Beef': 4}
# 10............
# Customer Name: Alice
# Password: asdzxc1234
# Cart Details:
# Total Item: 3
# Item: Mango, Unit: 10, Per Unit Price: 100, Total price: 1000
# Item: Ego Icecream, Unit: 4, Per Unit Price: 60, Total price: 240
# Item: Beef, Unit: 4, Per Unit Price: 650, Total price: 2600
# Total Cost: 3840
# 11............
# Customer Name: Bob
# Password: qwerty12
# Cart Details:
# Total Item: 4
# Item: Beef, Unit: 3, Per Unit Price: 650, Total price: 1950
# Item: Chicken, Unit: 5, Per Unit Price: 250, Total price: 1250
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-013f4cab4ba5> in <module>()
#      81 customer1.printDetails()
#      82 print("11............")
# ---> 83 customer2.printDetails()
#
# <ipython-input-20-013f4cab4ba5> in printDetails(self)
#      49     print(f"Customer Name: {self.name}\nPassword: {self.pass1}\nCart Details:\nTotal Item: {len(self.item)}")
#      50     for k,v in self.dic.items():
# ---> 51       total_price = product_list[k]*v
#      52       print(f"Item: {k}, Unit: {v}, Per Unit Price: {product_list[k]}, Total price: {total_price}")
#      53       total_cost +=total_price
#
# KeyError: 'Lichi'

# %%
#Driver code:

product_list=["Manggo":100,"Ego icecream":60,"Chocobar":25]
product_list["Beef"]=650
product_list["Chicken"]=250
product_list["Apple"] = 150
print("1.............")
customer1 = Customer("Alice","asdzxc1234")
print("2.............")
customer2 = Customer("Bob")
print("3.............")
customer1.addToCart("Mango",10,"Ego Icecream",4)
print("4.............")
customer2.addToCart("Beef",3,"Chicken",5)
print("5.............")
customer1.printDetails()
print("6.............")
customer2.printDetails()
print("7.............")
customer2.setPassword("qwerty12")
customer2.addToCart("Beef",3,"Chicken",5)
print("8.............")
customer2.addToCart("Lichi",100,"Apple",3)
print("9.............")
customer1.addToCart("Beef",4)
print("10............")
customer1.printDetais()
print("11............")
customer2.printDetails()

# %%
s = ["mango",11,"apple",12,"beef",13]
d = {}

for i in range(len(s)):

  if i%2==0:
    key = s[i]

  else:
    value = s[i]
  d[key]=value




print(d)
# Out:
# {'mango': 11, 'apple': 12, 'beef': 13}

# %%
ha hakkkkk
