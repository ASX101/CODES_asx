# %%
#ans to the question:


class TechShop:
  def __init__(self,shop):
    self.shop= shop
    self.product1 = None
    self.product2 = None

  def Product(self,name,category,code=0):
    self.name = name
    self.category = category
    self.code = code
  def addProduct(self,p = None,q= None):
    if p == None and q == None :
      print("Product without code can not be added")
    elif p != None and q == None:
      self.p = p
      print(f"Product with code:{self.p} added")

    elif p != None and q != None:
      self.p = p
      self.q= q
      print(f"Product with code:{self.p} added")
      print(f"Product with code:{self.q} added")
    

   
  def setCode(self,code):
    self.code = code
  def printProduct(self):
    print(f"Product name:{self.name} Category: {self.category} code: {self.code}")


obj = TechShop("Star Tech")
p1 = Product("Core i7 11700","Processor",16039)
print("=================================")
obj.addProduct(p1)
print("=================================")
obj.printProducts()
print("=================================")
p2 = Product("Ryzen 5900X","Processor")
p3 = Product("ASRock B550 Taichi","Motherboard",18080)
print("=================================")
obj.addProduct(p2,p3)
print("=================================")
obj.printProducts()
print("=================================")
p2.setCode(17699)
print("=================================")
obj.addProduct(p2)
print("=================================")
obj.printProducts()
print("=================================")
p4 = Product("ASUS ROG Strix Z390-F","Motherboard",8694)
p5 = Product("ASUS ROG Strix RTX3080","GPU",17071)
print("=================================")
obj.addProduct(p4,p5)
print("=================================")
obj.printProducts()
print("=================================")
# Out:
# ...
# Product with code:<__main__.Product object at 0x7f14a5a5ed10> added
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-211dd1e8cdcb> in <module>()
#      38 obj.addProduct(p1)
#      39 print("=================================")
# ---> 40 obj.printProducts()
#      41 print("=================================")
#      42 p2 = Product("Ryzen 5900X","Processor")
#
# AttributeError: 'TechShop' object has no attribute 'printProducts'
