# %%
#ans to the question no 1

List1=input().split(sep=",")
L=List1=[int(i) for i in List1]
print(List1)
List2=[]
for j in List1:
    count = 1
    total = 0
    while (count <= j):
        if (j % count == 0):
            count += 1
            total += 1
        else:
            count += 1
    if (total == 2 or j==1):
        List2.append(j)
List3=int()
for k in List2:
    List3+=k
print(List2)
if List3%2==0:
    print('Just another normal day!!!')
else:
    print('It’s a miracle!!!')
# Out:
# 10,12,2,14,17
# [10, 12, 2, 14, 17]
# [2, 17]
# It’s a miracle!!!

# %%
#ans to the question no 3

def function_name(List1,List2):
    updated_list= []
    if len(List1)==len(List2):
        for i in range(len(List1)):
            if List1[i]%2 !=0:
                List1[i]= i*2
                n = List1[i]
        for j in range(len(List2)):
            if List2[j]%2 != 0:
                z = str(List2)
                new = z.replace(str(List2[j]),str(List1[i]))
                updated_list.append(new)
                x = updated_list+List1
    else:
        print("The length of the lists are not equal")
    
    print(updated_list)
    
function_name([5,6,7],[6,8,2,9])
# Out:
# The length of the lists are not equal
# []
