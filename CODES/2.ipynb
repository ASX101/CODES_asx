# %%
#ans to 1:
my_dict= { "22/11/2021": [], "25/11/2021": [], "29/11/2021": []}
l = []
while True:
  command = input()
  l.append(command)

  if command == "STOP":
    break
for i in l:
  if "22/11/2021" in l:
    my_dict["22/11/2021"].append(i)
  elif "25/11/2021" in l:
    my_dict["25/11/2021"].append(i)
  else:
    my_dict["29/11/2021"].append(i)
print(my_dict)
# Out:
# cse111 quiz2 22/11/2021
# cse221 mid 29/11/2021
# cse320 quiz3 25/11/2021
# cse221 quiz2 22/11/2021
# STOP
# {'22/11/2021': [], '25/11/2021': [], '29/11/2021': ['cse111 quiz2 22/11/2021', 'cse221 mid 29/11/2021', 'cse320 quiz3 25/11/2021', 'cse221 quiz2 22/11/2021', 'STOP']}

# %%
#ans to 2:

class Vehicle:
  def __init__(self,number,vehicle,company,fareChart):
    self.number = number
    self.vehicle = vehicle 
    self.company = company
  def addPassenger(self,p_name,q_name="Dhaka"):
    self.pass_name = p_name.name
    self.new_name_2 = p_name.name
    if self.pass_name != "Dhaka":
      print(f"This is an inter_city bus.{self.new_name_2} can not take the bus")
    else:
      print(f"{self.pass_name} has taken the bus")


    
class Passenger:
  def __init__(self,name,destination=None):
    self.name = name
    self.destination = destination
    if self.destination == None:
      print("Destination can not be empty")
  def calculateFare(self,fare):
    
    print(f"Calculating fare for {self.name}")
  def setDestination(self,new_d):
    self.new_d = new_d
    print(f"Destination of {self.name} is updated to {self.new_d}")
  





fareChart = {'SR Travels': 40, 'ENA': 50, 'Pathao': 200, 'Uber': 250, 'Hanif Paribahan': 45, 'Others': 90 }
v1 = Vehicle("Dhaka-123", "Bus", 'SR Travels', fareChart)
p1 = Passenger("Sam", "Dhaka")
print("1.===========================")
v1.addPassenger(p1)
print("2.===========================")
p1.calculateFare(v1)
print("3.===========================")
p2 = Passenger("John", "Dhaka")
p3 = Passenger("Bran")
print("4.===========================")
p3.setDestination("Chittagong")
print("5.===========================")
v1.addPassenger(p2, p3)
print("6.===========================")
p2.calculateFare(v1)
print("7.===========================")
p4 = Passenger("Mark", "Dhaka")
p5 = Passenger("Jack", "Khulna")
v1.addPassenger(p4, p5)
print("8.===========================")
p4.calculateFare(v1)
print("===========================")
v2 = Vehicle("Chittagong-798", "Car", "Uber", fareChart)
print("9.===========================")
v2.addPassenger(p1)
v2.addPassenger(p3)
print("10.===========================")
p3.calculateFare(v2)
print("11.===========================")
v3 = Vehicle("Khulna-997", "Car", "Obhai", fareChart)
v3.addPassenger(p5)
print("12.===========================")
p5.calculateFare(v3)
print("13.===========================")
# Out:
# 1.===========================
# This is an inter_city bus.Sam can not take the bus
# 2.===========================
# Calculating fare for Sam
# 3.===========================
# Destination can not be empty
# 4.===========================
# Destination of Bran is updated to Chittagong
# 5.===========================
# This is an inter_city bus.John can not take the bus
# 6.===========================
# Calculating fare for John
# 7.===========================
# This is an inter_city bus.Mark can not take the bus
# 8.===========================
# Calculating fare for Mark
# ...
# 9.===========================
# This is an inter_city bus.Sam can not take the bus
# This is an inter_city bus.Bran can not take the bus
# 10.===========================
# Calculating fare for Bran
# 11.===========================
# This is an inter_city bus.Jack can not take the bus
# 12.===========================
# Calculating fare for Jack
# 13.===========================
