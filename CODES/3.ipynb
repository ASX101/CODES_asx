# %%
#ans


class Traveller:
  count = 0
  cost= 0
  def __init__(self,name):
    self.name = name
    Traveller.count += 1
    
  def buyTickets(self,dest1,cost1,dest2= "",cost2=None,dest3="",cost3 = None):
    self.dest1 = dest1
    self.cost1 = cost1
    self.dest2 = dest2
    self.cost2 = cost2
    self.dest3 = dest3
    self.cost3 = cost3
    Traveller.cost = self.cost1
    if self.cost2 != None and self.cost3 != None:
      
      Traveller.cost = self.cost2+ self.cost3

      
  
    elif self.cost2 != None and self.cost3 == None:
      Traveller.cost = self.cost1 
      Traveller.cost += self.cost2
      pass
    elif self.cost2 == None and self.cost3 == None:
      Traveller.cost = self.cost1
      pass
  
  def printDetail(self):
    print(f"Name: {self.name}")
    print(f"Tickets:{self.dest1},{self.dest2},{self.dest3}")
    print("Cost:",Traveller.cost)

print("Total Traveller:", Traveller.count)
t1 = Traveller("Naruto")
t1.buyTickets("Mist Village",5000,"Rain Village", 10000)
t2 = Traveller("Minato")
t2.buyTickets("Cloud Village",15000,"Sand Village",1200,"Stone Village", 
5000)
t3 = Traveller("Kushina")
t3.buyTickets("Leaves Village", 3000)
print("=========================")
t1.printDetail()
print("=========================")
t2.printDetail()
print("=========================")
t3.printDetail()
print("=========================")
print("Total Traveller:", Traveller.count)
# Out:
# Total Traveller: 0
# ...
# Name: Naruto
# Tickets:Mist Village,Rain Village,
# Cost: 3000
# ...
# Name: Minato
# Tickets:Cloud Village,Sand Village,Stone Village
# Cost: 3000
# ...
# Name: Kushina
# Tickets:Leaves Village,,
# Cost: 3000
# ...
# Total Traveller: 3
