# %%
radius= float(input('enter a radius'))
area = 3.1416 * radius **2
circumference = 2 * 3.1416 * radius
print('area=',area)
print('circumference=',circumference)
# Out:
# enter a radius9.5
# area= 283.5294
# circumference= 59.6904
